# %% [markdown]
# # This is running the Random Forest (RF) models, all dataset folders at once.
#
# The model takes the image data from a root folder (greyscale/gy. original(RBG)/og or Four-channel/fc and runs them through a random forest model.
#
# VERSIONS
#
# Outputs are to the 3 (_gy, _or, _fc) data folders which themselves reflect the quality of the data provided.
#
# PARAMETERS
# It adjusts the data to the 3 datasizes used in the KNN and Random Forest Models (64x64,128x128,256x256)
#
# The 3x3 grid search is number of estimators x max depth
#
# The model uses 5-fold on the 80% 'training-validation' data.  The data includes 20% for final testing.
#
# LOCALISATION
#
# root_folders - these are the sources of data (right at the end of each code block)
# Adjust as needed.
#
# It is assumed that earlier models and pip's have been installed.
#
# TIMING
#
# The models (when run in series and with concurrent cores) ran in 30 mins.
# This is indicative as depends on the resources available.
#
# RESULTS
#
# each model x imagesize combination generates an excel file with results and logs
# These are saved in the related root folders.

# %%
import os
import numpy as np
import cv2
import time
import pandas as pd
from sklearn.model_selection import KFold, cross_val_score, train_test_split
#from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from datetime import datetime
import concurrent.futures
import sys

# Function to load and preprocess images
def load_images_from_folder(folder, target_size):
    images = []
    labels = []
    class_names = os.listdir(folder)
    filenames = []
    for label, class_name in enumerate(class_names):
        class_folder = os.path.join(folder, class_name)
        for filename in os.listdir(class_folder):
            img_path = os.path.join(class_folder, filename)
            img = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
            if img is not None:
                # Handle different bit depths
                if len(img.shape) == 2:  # Grayscale image
                    img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
                elif img.shape[2] == 4:  # 4-channel image (e.g., RGBA)
                    img = img[:, :, :3]  # Discard the alpha channel

                img = cv2.resize(img, target_size)  # Resize to target_size
                images.append(img)
                labels.append(label)
                filenames.append(filename)
    return np.array(images), np.array(labels), class_names, filenames

# Function to preprocess and flatten images
def preprocess_images(X, target_size):
    X_resized = []
    for img in X:
        img_resized = cv2.resize(img, target_size)
        X_resized.append(img_resized)
    X_resized = np.array(X_resized).astype('float32') / 255.0
    return X_resized.reshape((X_resized.shape[0], -1))

# Define parameter grid for GridSearchCV
param_grid = {
    'n_estimators': [10, 50, 100],
    'criterion': ['gini'
#                  , 'entropy'
                 ],
    'max_depth': [
        None, 
        10, 
        20, 
#        30
    ],
    'min_samples_split': [2
#    , 5, 10
                         ],
    'min_samples_leaf': [1
#    , 2, 4
    ]
}

image_sizes = [(64, 64), (128, 128), (256, 256)]

def run_model(train_dataset_folder, test_dataset_folder, model_type, root_folder_suffix):
    # Record start time for the model processing
    model_start_time = datetime.now()
    log = []
    log.append(f"Processing {root_folder_suffix}:{model_type} - Started at {model_start_time}")
    print(f"Processing {root_folder_suffix}:{model_type} - Started at {model_start_time}")

    # Load and preprocess training data
    log.append(f"Processing {root_folder_suffix}:{model_type} - Loading and preprocessing training data")
    print(f"Processing {root_folder_suffix}:{model_type} - Loading and preprocessing training data")
    start_time = time.time()
    X_train_orig, y_train, class_names, train_filenames = load_images_from_folder(train_dataset_folder, target_size=(128, 128))
    load_preprocess_time = time.time() - start_time
    log.append(f"Processing {root_folder_suffix}:{model_type} - Time taken for loading and preprocessing: {load_preprocess_time:.2f} seconds")
    print(f"Processing {root_folder_suffix}:{model_type} - Time taken for loading and preprocessing: {load_preprocess_time:.2f} seconds")

    best_params = None
    best_score = 0
    best_target_size = None
    best_conf_matrix = None
    best_X_train_resized = None

    # K-Fold Cross-Validation
    kf = KFold(n_splits=5, shuffle=True, random_state=42)

    timing_results = []
    cm_results = []

    for target_size in image_sizes:
        start_size_time = time.time()
        log.append(f"Processing {root_folder_suffix}:{model_type} - Evaluating for image size: {target_size}")
        print(f"Processing {root_folder_suffix}:{model_type} - Evaluating for image size: {target_size}")

        X_train_resized = preprocess_images(X_train_orig, target_size)

        for n_estimators in param_grid['n_estimators']:
            for criterion in param_grid['criterion']:
                for max_depth in param_grid['max_depth']:
                    for min_samples_split in param_grid['min_samples_split']:
                        for min_samples_leaf in param_grid['min_samples_leaf']:
                            params = {
                                'n_estimators': n_estimators,
                                'criterion': criterion,
                                'max_depth': max_depth,
                                'min_samples_split': min_samples_split,
                                'min_samples_leaf': min_samples_leaf
                            }
                            rf = RandomForestClassifier(**params)

                            start_grid_item_time = time.time()
                            scores = cross_val_score(rf, X_train_resized, y_train, cv=kf, scoring='accuracy')
                            grid_item_time = time.time() - start_grid_item_time

                            mean_score = scores.mean()
                            timing_results.append({
                                'image_size': target_size,
                                'n_estimators': n_estimators,
                                'criterion': criterion,
                                'max_depth': max_depth,
                                'min_samples_split': min_samples_split,
                                'min_samples_leaf': min_samples_leaf,
                                'mean_score': mean_score,
                                'time': grid_item_time,
                                'scoring_metric': 'accuracy'
                            })

                            log.append(f"Processing {root_folder_suffix}:{model_type} - Params: {params} - Mean Score (accuracy): {mean_score:.4f} - Time: {grid_item_time:.2f} seconds")
                            print(f"Processing {root_folder_suffix}:{model_type} - Params: {params} - Mean Score (accuracy): {mean_score:.4f} - Time: {grid_item_time:.2f} seconds")

                            # Collect confusion matrix for the current model
                            X_train_split, X_valid_split, y_train_split, y_valid_split = train_test_split(X_train_resized, y_train, test_size=0.2, random_state=42)
                            rf.fit(X_train_split, y_train_split)
                            y_valid_pred = rf.predict(X_valid_split)
                            cm = confusion_matrix(y_valid_split, y_valid_pred)
                            cm_results.append({
                                'image_size': target_size,
                                'params': params,
                                'confusion_matrix': cm
                            })

                            if mean_score > best_score:
                                best_score = mean_score
                                best_params = params
                                best_target_size = target_size
                                best_conf_matrix = cm
                                best_X_train_resized = X_train_resized

        size_time = time.time() - start_size_time
        log.append(f"Processing {root_folder_suffix}:{model_type} - Total time taken for image size {target_size}: {size_time:.2f} seconds\n")
        print(f"Processing {root_folder_suffix}:{model_type} - Total time taken for image size {target_size}: {size_time:.2f} seconds\n")

    log.append(f"Processing {root_folder_suffix}:{model_type} - Best Score: {best_score}")
    log.append(f"Processing {root_folder_suffix}:{model_type} - Best Parameters: {best_params}")
    log.append(f"Processing {root_folder_suffix}:{model_type} - Best Image Size: {best_target_size}")
    print(f"Processing {root_folder_suffix}:{model_type} - Best Score: {best_score}")
    print(f"Processing {root_folder_suffix}:{model_type} - Best Parameters: {best_params}")
    print(f"Processing {root_folder_suffix}:{model_type} - Best Image Size: {best_target_size}")

    # Save results
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    result_folder = os.path.dirname(train_dataset_folder)
    file_path = os.path.join(result_folder, f"{root_folder_suffix}_{model_type}_RF_results_{timestamp}.xlsx")

    with pd.ExcelWriter(file_path, engine='xlsxwriter') as writer:
        # Save best parameters
        best_params_df = pd.DataFrame([best_params])
        best_params_df['image_size'] = [best_target_size]
        best_params_df.to_excel(writer, sheet_name='Best_Parameters', index=False)

        # Save timing results
        timing_df = pd.DataFrame(timing_results)
        timing_df.to_excel(writer, sheet_name='Timing_Results', index=False)

        # Save confusion matrices for all grid search iterations
        cm_data = []
        for cm_result in cm_results:
            for i in range(len(class_names)):
                for j in range(len(class_names)):
                    cm_data.append({
                        'image_size': cm_result['image_size'],
                        'params': cm_result['params'],
                        'true_class': class_names[i],
                        'predicted_class': class_names[j],
                        'count': cm_result['confusion_matrix'][i, j]
                    })
        cm_df = pd.DataFrame(cm_data)
        cm_df.to_excel(writer, sheet_name='Confusion_Matrices', index=False)

    log.append(f"Processing {root_folder_suffix}:{model_type} - Grid search results saved to {file_path}")
    print(f"Processing {root_folder_suffix}:{model_type} - Grid search results saved to {file_path}")

    # Load the test dataset with best image size
    log.append(f"Processing {root_folder_suffix}:{model_type} - Loading and preprocessing test data")
    print(f"Processing {root_folder_suffix}:{model_type} - Loading and preprocessing test data")
    X_test_orig, y_test, _, test_filenames = load_images_from_folder(test_dataset_folder, target_size=best_target_size)

    # Preprocess test images
    X_test_resized = preprocess_images(X_test_orig, best_target_size)

    # Evaluate the final model on the test dataset
    start_time = time.time()
    final_model = RandomForestClassifier(**best_params)
    final_model.fit(best_X_train_resized, y_train)
    train_time = time.time() - start_time

    start_time = time.time()
    y_test_pred = final_model.predict(X_test_resized)
    predict_time = time.time() - start_time

    test_accuracy = accuracy_score(y_test, y_test_pred)
    log.append(f"Processing {root_folder_suffix}:{model_type} - Test Accuracy: {test_accuracy:.4f}")
    log.append(f"Processing {root_folder_suffix}:{model_type} - Time taken for final training: {train_time:.2f} seconds")
    log.append(f"Processing {root_folder_suffix}:{model_type} - Time taken for final prediction: {predict_time:.2f} seconds")
    log.append(f"Processing {root_folder_suffix}:{model_type} - Test Classification Report:\n{classification_report(y_test, y_test_pred, target_names=class_names)}")
    log.append(f"Processing {root_folder_suffix}:{model_type} - Test Confusion Matrix:\n{confusion_matrix(y_test, y_test_pred)}")
    print(f"Processing {root_folder_suffix}:{model_type} - Test Accuracy: {test_accuracy:.4f}")
    print(f"Processing {root_folder_suffix}:{model_type} - Time taken for final training: {train_time:.2f} seconds")
    print(f"Processing {root_folder_suffix}:{model_type} - Time taken for final prediction: {predict_time:.2f} seconds")
    print(f"Processing {root_folder_suffix}:{model_type} - Test Classification Report:\n{classification_report(y_test, y_test_pred, target_names=class_names)}")
    print(f"Processing {root_folder_suffix}:{model_type} - Test Confusion Matrix:\n{confusion_matrix(y_test, y_test_pred)}")

    # Save final test results
    with pd.ExcelWriter(file_path, engine='openpyxl', mode='a') as writer:
        # Save test classification report
        test_report = classification_report(y_test, y_test_pred, target_names=class_names, output_dict=True)
        test_report_df = pd.DataFrame(test_report).transpose()
        test_report_df.to_excel(writer, sheet_name='Test_Classification_Report')

        # Save test confusion matrix
        test_cm = confusion_matrix(y_test, y_test_pred)
        test_cm_df = pd.DataFrame(test_cm, index=class_names, columns=class_names)
        test_cm_df.to_excel(writer, sheet_name='Test_Confusion_Matrix')

        # Save image predictions
        predictions_df = pd.DataFrame({
            'Filename': test_filenames,
            'Actual': [class_names[label] for label in y_test],
            'Predicted': [class_names[label] for label in y_test_pred]
        })
        predictions_df.to_excel(writer, sheet_name='Image_Predictions', index=False)

        # Save summary
        summary_data = {
            'Best Score': [best_score],
            'Best Parameters': [best_params],
            'Best Image Size': [best_target_size],
            'Test Accuracy': [test_accuracy],
            'Training Time': [train_time],
            'Prediction Time': [predict_time]
        }
        summary_df = pd.DataFrame(summary_data)
        summary_df.to_excel(writer, sheet_name='Summary', index=False)

        # Save log
        log_df = pd.DataFrame(log, columns=['Log'])
        log_df.to_excel(writer, sheet_name='Log', index=False)

    # Record end time for the model processing
    model_end_time = datetime.now()
    log.append(f"Processing {root_folder_suffix}:{model_type} - Ended at {model_end_time}")
    log.append(f"Processing {root_folder_suffix}:{model_type} - Total duration: {model_end_time - model_start_time}")
    log.append(f"Processing {root_folder_suffix}:{model_type} - Best Parameters identified from the grid search: {best_params}")
    log.append(f"Processing {root_folder_suffix}:{model_type} - Best Image Size identified from the grid search: {best_target_size}")
    log.append(f"Processing {root_folder_suffix}:{model_type} - Final test results saved to {file_path}")
    print(f"Processing {root_folder_suffix}:{model_type} - Ended at {model_end_time}")
    print(f"Processing {root_folder_suffix}:{model_type} - Total duration: {model_end_time - model_start_time}")
    print(f"Processing {root_folder_suffix}:{model_type} - Best Parameters identified from the grid search: {best_params}")
    print(f"Processing {root_folder_suffix}:{model_type} - Best Image Size identified from the grid search: {best_target_size}")
    print(f"Processing {root_folder_suffix}:{model_type} - Final test results saved to {file_path}")

# Function to iterate over the data directories and run the model
def run_models_for_all_datasets(root_folders):
    # Record start time for the overall processing
    overall_start_time = datetime.now()
    print(f"Overall processing started at {overall_start_time}")

    model_types = ['country', 'exact_piece', 'force', 'piece']

    tasks = []

    for root_folder in root_folders:
        root_folder_suffix = os.path.basename(root_folder)[-2:]
        for model_type in model_types:
            train_folder = os.path.join(root_folder, f"{model_type}_train")
            test_folder = os.path.join(root_folder, f"{model_type}_test")

            if os.path.exists(train_folder) and os.path.exists(test_folder):
                tasks.append((train_folder, test_folder, model_type, root_folder_suffix))
            else:
                print(f"Skipping {model_type} in {root_folder} as train or test folder does not exist")

    # Run models in parallel
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [executor.submit(run_model, train, test, model, suffix) for train, test, model, suffix in tasks]
        for future in concurrent.futures.as_completed(futures):
            try:
                future.result()
            except Exception as exc:
                print(f"Generated an exception: {exc}")

    # Record end time for the overall processing
    overall_end_time = datetime.now()
    print(f"Overall processing ended at {overall_end_time}")
    print(f"Total duration for all models: {overall_end_time - overall_start_time}")

# List of root folders
root_folders = [
    'C:\\Users\\ReCas\\OneDrive\\Documents\\2024_AIMachineLearning\\99_Projects\\06.DataSets_gy',
    'C:\\Users\\ReCas\\OneDrive\\Documents\\2024_AIMachineLearning\\99_Projects\\07.DataSets_or',
    'C:\\Users\\ReCas\\OneDrive\\Documents\\2024_AIMachineLearning\\99_Projects\\08.DataSets_fc'
]

# Run the models for all datasets
run_models_for_all_datasets(root_folders)
# Out:
# Overall processing started at 2024-08-05 21:55:03.197141
# Processing gy:country - Started at 2024-08-05 21:55:03.199140
# Processing gy:country - Loading and preprocessing training data
# Processing gy:exact_piece - Started at 2024-08-05 21:55:03.200140
# Processing gy:exact_piece - Loading and preprocessing training data
# Processing gy:force - Started at 2024-08-05 21:55:03.200140
# Processing gy:force - Loading and preprocessing training data
# Processing gy:piece - Started at 2024-08-05 21:55:03.201141
# Processing gy:piece - Loading and preprocessing training data
# Processing or:country - Started at 2024-08-05 21:55:03.201141
# Processing or:country - Loading and preprocessing training data
# Processing or:exact_piece - Started at 2024-08-05 21:55:03.201141
# Processing or:exact_piece - Loading and preprocessing training data
# Processing or:force - Started at 2024-08-05 21:55:03.202141
# Processing or:force - Loading and preprocessing training data
# Processing or:piece - Started at 2024-08-05 21:55:03.202141
# Processing or:piece - Loading and preprocessing training data
# Processing fc:country - Started at 2024-08-05 21:55:03.202141
# Processing fc:country - Loading and preprocessing training data
# Processing fc:exact_piece - Started at 2024-08-05 21:55:03.203141
# Processing fc:exact_piece - Loading and preprocessing training data
# Processing fc:force - Started at 2024-08-05 21:55:03.203141
# Processing fc:force - Loading and preprocessing training data
# Processing fc:piece - Started at 2024-08-05 21:55:03.203141
# Processing fc:piece - Loading and preprocessing training data
# Processing gy:exact_piece - Time taken for loading and preprocessing: 40.84 seconds
# Processing gy:exact_piece - Evaluating for image size: (64, 64)
# Processing gy:country - Time taken for loading and preprocessing: 40.89 seconds
# Processing gy:country - Evaluating for image size: (64, 64)
# Processing gy:force - Time taken for loading and preprocessing: 42.51 seconds
# Processing gy:force - Evaluating for image size: (64, 64)
# Processing gy:piece - Time taken for loading and preprocessing: 42.65 seconds
# Processing gy:piece - Evaluating for image size: (64, 64)
# Processing gy:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7042 - Time: 3.52 seconds
# Processing gy:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9681 - Time: 1.99 seconds
# Processing gy:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8889 - Time: 2.69 seconds
# Processing gy:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7059 - Time: 5.54 seconds
# Processing gy:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9584 - Time: 2.00 seconds
# Processing gy:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6528 - Time: 2.52 seconds
# Processing gy:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8733 - Time: 2.52 seconds
# Processing gy:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9633 - Time: 2.06 seconds
# Processing gy:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.5678 - Time: 3.24 seconds
# Processing gy:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7051 - Time: 3.75 seconds
# Processing gy:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8799 - Time: 3.05 seconds
# Processing gy:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6945 - Time: 5.02 seconds
# Processing gy:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9796 - Time: 9.89 seconds
# Processing gy:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9232 - Time: 12.13 seconds
# Processing gy:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7557 - Time: 16.15 seconds
# Processing gy:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9788 - Time: 8.87 seconds
# Processing or:piece - Time taken for loading and preprocessing: 78.49 seconds
# Processing or:piece - Evaluating for image size: (64, 64)
# Processing gy:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9101 - Time: 11.34 seconds
# Processing or:country - Time taken for loading and preprocessing: 78.70 seconds
# Processing or:country - Evaluating for image size: (64, 64)
# Processing or:exact_piece - Time taken for loading and preprocessing: 78.86 seconds
# Processing or:exact_piece - Evaluating for image size: (64, 64)
# Processing or:force - Time taken for loading and preprocessing: 78.92 seconds
# Processing or:force - Evaluating for image size: (64, 64)
# Processing or:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9690 - Time: 2.19 seconds
# Processing or:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8856 - Time: 2.90 seconds
# Processing gy:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9771 - Time: 9.76 seconds
# Processing or:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7042 - Time: 3.92 seconds
# Processing or:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9608 - Time: 2.28 seconds
# Processing gy:exact_piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7549 - Time: 26.69 seconds
# Processing gy:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7467 - Time: 12.48 seconds
# Processing or:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8783 - Time: 2.83 seconds
# Processing or:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7051 - Time: 6.04 seconds
# Processing or:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6847 - Time: 2.91 seconds
# Processing or:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9624 - Time: 2.23 seconds
# Processing or:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8880 - Time: 2.73 seconds
# Processing or:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.5948 - Time: 3.56 seconds
# Processing or:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6977 - Time: 3.74 seconds
# Processing gy:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9224 - Time: 13.24 seconds
# Processing or:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6879 - Time: 5.14 seconds
# Processing or:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9812 - Time: 10.41 seconds
# Processing fc:exact_piece - Time taken for loading and preprocessing: 98.13 seconds
# Processing fc:exact_piece - Evaluating for image size: (64, 64)
# Processing fc:force - Time taken for loading and preprocessing: 98.34 seconds
# Processing fc:force - Evaluating for image size: (64, 64)
# Processing fc:piece - Time taken for loading and preprocessing: 98.41 seconds
# Processing fc:piece - Evaluating for image size: (64, 64)
# Processing fc:country - Time taken for loading and preprocessing: 98.46 seconds
# Processing fc:country - Evaluating for image size: (64, 64)
# Processing fc:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9747 - Time: 2.27 seconds
# Processing fc:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8872 - Time: 2.73 seconds
# Processing or:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9134 - Time: 13.24 seconds
# Processing fc:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7059 - Time: 3.76 seconds
# Processing fc:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9649 - Time: 2.11 seconds
# Processing fc:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7230 - Time: 5.76 seconds
# Processing gy:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7582 - Time: 16.85 seconds
# Processing fc:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8815 - Time: 2.60 seconds
# Processing gy:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9804 - Time: 20.41 seconds
# Processing fc:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6895 - Time: 2.84 seconds
# Processing fc:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9714 - Time: 2.27 seconds
# Processing gy:exact_piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6814 - Time: 15.64 seconds
# Processing fc:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8766 - Time: 2.70 seconds
# Processing fc:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.5907 - Time: 3.38 seconds
# Processing or:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7647 - Time: 17.74 seconds
# Processing or:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9796 - Time: 10.11 seconds
# Processing fc:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6904 - Time: 3.78 seconds
# Processing fc:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6969 - Time: 4.86 seconds
# Processing fc:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9788 - Time: 10.04 seconds
# Processing or:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9126 - Time: 12.27 seconds
# Processing fc:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9232 - Time: 12.32 seconds
# Processing or:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9788 - Time: 9.80 seconds
# Processing gy:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9232 - Time: 25.42 seconds
# Processing or:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7378 - Time: 12.03 seconds
# Processing or:exact_piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7524 - Time: 28.40 seconds
# Processing gy:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9788 - Time: 18.55 seconds
# Processing fc:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7615 - Time: 16.65 seconds
# Processing fc:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9796 - Time: 9.51 seconds
# Processing or:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9175 - Time: 12.71 seconds
# Processing gy:exact_piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7500 - Time: 23.65 seconds
# Processing fc:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9134 - Time: 11.93 seconds
# Processing fc:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9788 - Time: 10.06 seconds
# Processing gy:country - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7606 - Time: 33.15 seconds
# Processing fc:exact_piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7565 - Time: 27.64 seconds
# Processing or:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9804 - Time: 19.44 seconds
# Processing fc:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7435 - Time: 12.38 seconds
# Processing or:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7713 - Time: 16.67 seconds
# Processing or:exact_piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6879 - Time: 15.07 seconds
# Processing fc:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9207 - Time: 11.99 seconds
# Processing gy:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9771 - Time: 18.84 seconds
# Processing gy:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9191 - Time: 23.44 seconds
# Processing gy:force - Total time taken for image size (64, 64): 111.26 seconds
#
# Processing gy:force - Evaluating for image size: (128, 128)
# Processing gy:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9624 - Time: 4.62 seconds
# Processing or:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9216 - Time: 24.65 seconds
# Processing fc:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9780 - Time: 19.13 seconds
# Processing fc:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7598 - Time: 16.53 seconds
# Processing fc:exact_piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6789 - Time: 14.84 seconds
# Processing gy:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9534 - Time: 4.54 seconds
# Processing or:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9820 - Time: 19.13 seconds
# Processing gy:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9673 - Time: 4.50 seconds
# Processing gy:country - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7378 - Time: 23.62 seconds
# Processing or:exact_piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7443 - Time: 23.15 seconds
# Processing fc:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9248 - Time: 24.24 seconds
# Processing gy:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9216 - Time: 24.75 seconds
# Processing or:country - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7688 - Time: 33.28 seconds
# Processing fc:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9771 - Time: 18.64 seconds
# Processing gy:piece - Total time taken for image size (64, 64): 142.45 seconds
#
# Processing gy:piece - Evaluating for image size: (128, 128)
# Processing or:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9199 - Time: 23.48 seconds
# Processing or:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9763 - Time: 19.18 seconds
# Processing fc:exact_piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7500 - Time: 23.06 seconds
# Processing gy:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7566 - Time: 52.69 seconds
# Processing gy:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8774 - Time: 5.67 seconds
# Processing gy:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9845 - Time: 20.55 seconds
# Processing or:force - Total time taken for image size (64, 64): 113.84 seconds
#
# Processing or:force - Evaluating for image size: (128, 128)
# Processing or:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9640 - Time: 4.82 seconds
# Processing gy:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8774 - Time: 5.91 seconds
# Processing fc:country - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7598 - Time: 33.58 seconds
# Processing or:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9657 - Time: 4.62 seconds
# Processing fc:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9232 - Time: 23.50 seconds
# Processing gy:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8709 - Time: 6.38 seconds
# Processing fc:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9804 - Time: 20.03 seconds
# Processing gy:country - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7631 - Time: 32.24 seconds
# Processing or:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9641 - Time: 4.67 seconds
# Processing fc:force - Total time taken for image size (64, 64): 112.57 seconds
#
# Processing fc:force - Evaluating for image size: (128, 128)
# Processing or:country - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7590 - Time: 25.05 seconds
# Processing gy:country - Total time taken for image size (64, 64): 173.81 seconds
#
# Processing gy:country - Evaluating for image size: (128, 128)
# Processing gy:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9796 - Time: 20.45 seconds
# Processing fc:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9641 - Time: 4.79 seconds
# Processing or:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9191 - Time: 24.82 seconds
# Processing fc:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9673 - Time: 4.64 seconds
# Processing or:piece - Total time taken for image size (64, 64): 143.40 seconds
#
# Processing or:piece - Evaluating for image size: (128, 128)
# Processing gy:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7067 - Time: 7.90 seconds
# Processing fc:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9616 - Time: 4.59 seconds
# Processing or:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8717 - Time: 6.17 seconds
# Processing gy:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6830 - Time: 5.58 seconds
# Processing fc:country - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7451 - Time: 24.60 seconds
# Processing or:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9812 - Time: 21.05 seconds
# Processing or:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7541 - Time: 54.76 seconds
# Processing gy:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7075 - Time: 29.86 seconds
# Processing gy:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9150 - Time: 26.70 seconds
# Processing fc:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9199 - Time: 24.45 seconds
# Processing or:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8783 - Time: 5.87 seconds
# Processing fc:piece - Total time taken for image size (64, 64): 139.94 seconds
#
# Processing fc:piece - Evaluating for image size: (128, 128)
# Processing gy:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6969 - Time: 7.61 seconds
# Processing gy:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9812 - Time: 20.65 seconds
# Processing or:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8774 - Time: 5.93 seconds
# Processing fc:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8725 - Time: 5.81 seconds
# Processing fc:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9804 - Time: 20.68 seconds
# Processing fc:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7516 - Time: 54.88 seconds
# Processing fc:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8701 - Time: 5.52 seconds
# Processing or:country - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7794 - Time: 33.62 seconds
# Processing or:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9820 - Time: 20.35 seconds
# Processing or:country - Total time taken for image size (64, 64): 179.30 seconds
#
# Processing or:country - Evaluating for image size: (128, 128)
# Processing fc:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8799 - Time: 5.84 seconds
# Processing gy:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9240 - Time: 25.50 seconds
# Processing or:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7059 - Time: 7.84 seconds
# Processing fc:country - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7696 - Time: 32.65 seconds
# Processing or:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9167 - Time: 27.00 seconds
# Processing or:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7173 - Time: 30.17 seconds
# Processing fc:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9804 - Time: 20.20 seconds
# Processing or:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6748 - Time: 5.75 seconds
# Processing fc:country - Total time taken for image size (64, 64): 176.20 seconds
#
# Processing fc:country - Evaluating for image size: (128, 128)
# Processing gy:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7655 - Time: 35.60 seconds
# Processing or:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9812 - Time: 20.96 seconds
# Processing or:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6920 - Time: 8.14 seconds
# Processing fc:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7198 - Time: 7.97 seconds
# Processing gy:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7533 - Time: 46.80 seconds
# Processing gy:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9780 - Time: 40.54 seconds
# Processing fc:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9183 - Time: 27.46 seconds
# Processing fc:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7149 - Time: 30.26 seconds
# Processing fc:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6789 - Time: 5.85 seconds
# Processing gy:exact_piece - Total time taken for image size (64, 64): 253.02 seconds
#
# Processing gy:exact_piece - Evaluating for image size: (128, 128)
# Processing gy:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9232 - Time: 27.45 seconds
# Processing fc:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9820 - Time: 21.43 seconds
# Processing fc:country - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6994 - Time: 7.98 seconds
# Processing or:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9191 - Time: 26.73 seconds
# Processing gy:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7051 - Time: 13.86 seconds
# Processing gy:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7280 - Time: 25.85 seconds
# Processing gy:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.5253 - Time: 6.65 seconds
# Processing fc:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9248 - Time: 25.76 seconds
# Processing or:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7631 - Time: 36.23 seconds
# Processing or:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9812 - Time: 40.29 seconds
# Processing or:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7541 - Time: 48.03 seconds
# Processing gy:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6748 - Time: 10.84 seconds
# Processing gy:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9796 - Time: 38.90 seconds
# Processing or:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9191 - Time: 26.76 seconds
# Processing or:exact_piece - Total time taken for image size (64, 64): 257.61 seconds
#
# Processing or:exact_piece - Evaluating for image size: (128, 128)
# Processing fc:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7672 - Time: 36.31 seconds
# Processing fc:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7500 - Time: 45.98 seconds
# Processing fc:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9788 - Time: 39.92 seconds
# Processing fc:piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9191 - Time: 26.47 seconds
# Processing gy:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7549 - Time: 34.91 seconds
# Processing or:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7018 - Time: 13.28 seconds
# Processing fc:exact_piece - Total time taken for image size (64, 64): 252.25 seconds
#
# Processing fc:exact_piece - Evaluating for image size: (128, 128)
# Processing or:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7386 - Time: 25.76 seconds
# Processing gy:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9224 - Time: 52.46 seconds
# Processing or:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.5490 - Time: 7.22 seconds
# Processing fc:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7075 - Time: 13.59 seconds
# Processing fc:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7304 - Time: 25.88 seconds
# Processing or:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9829 - Time: 39.54 seconds
# Processing or:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6699 - Time: 11.52 seconds
# Processing fc:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.5261 - Time: 7.13 seconds
# Processing gy:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9788 - Time: 40.50 seconds
# Processing fc:exact_piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6863 - Time: 11.16 seconds
# Processing gy:force - Total time taken for image size (128, 128): 234.62 seconds
#
# Processing gy:force - Evaluating for image size: (256, 256)
# Processing fc:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9804 - Time: 39.69 seconds
# Processing or:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9248 - Time: 53.43 seconds
# Processing or:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7598 - Time: 36.30 seconds
# Processing gy:exact_piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7639 - Time: 65.08 seconds
# Processing gy:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9673 - Time: 10.20 seconds
# Processing fc:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9248 - Time: 52.87 seconds
# Processing gy:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9681 - Time: 10.39 seconds
# Processing fc:country - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7680 - Time: 36.54 seconds
# Processing gy:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9199 - Time: 51.87 seconds
# Processing or:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9820 - Time: 41.45 seconds
# Processing gy:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9690 - Time: 9.81 seconds
# Processing gy:country - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7565 - Time: 72.22 seconds
# Processing or:force - Total time taken for image size (128, 128): 237.56 seconds
#
# Processing or:force - Evaluating for image size: (256, 256)
# Processing fc:force - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9812 - Time: 42.19 seconds
# Processing or:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9624 - Time: 10.41 seconds
# Processing or:exact_piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7590 - Time: 67.49 seconds
# Processing gy:exact_piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6806 - Time: 32.41 seconds
# Processing fc:force - Total time taken for image size (128, 128): 238.78 seconds
#
# Processing fc:force - Evaluating for image size: (256, 256)
# Processing or:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9690 - Time: 10.24 seconds
# Processing fc:exact_piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7590 - Time: 66.65 seconds
# Processing or:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9281 - Time: 52.78 seconds
# Processing fc:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9698 - Time: 10.56 seconds
# Processing or:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9682 - Time: 10.84 seconds
# Processing gy:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9812 - Time: 41.58 seconds
# Processing fc:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9207 - Time: 53.45 seconds
# Processing fc:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9788 - Time: 10.55 seconds
# Processing or:country - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7696 - Time: 75.52 seconds
# Processing gy:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9273 - Time: 56.73 seconds
# Processing fc:force - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9706 - Time: 10.40 seconds
# Processing or:exact_piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6904 - Time: 34.22 seconds
# Processing gy:piece - Total time taken for image size (128, 128): 309.57 seconds
#
# Processing gy:piece - Evaluating for image size: (256, 256)
# Processing fc:country - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7729 - Time: 76.29 seconds
# Processing gy:country - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7427 - Time: 52.98 seconds
# Processing fc:exact_piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6740 - Time: 33.69 seconds
# Processing gy:exact_piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7402 - Time: 55.88 seconds
# Processing gy:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8954 - Time: 13.05 seconds
# Processing or:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9812 - Time: 41.42 seconds
# Processing gy:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9771 - Time: 39.15 seconds
# Processing or:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9240 - Time: 55.14 seconds
# Processing gy:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8946 - Time: 12.08 seconds
# Processing fc:force - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9763 - Time: 39.57 seconds
# Processing or:piece - Total time taken for image size (128, 128): 311.48 seconds
#
# Processing or:piece - Evaluating for image size: (256, 256)
# Processing fc:piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.9265 - Time: 54.03 seconds
# Processing gy:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8758 - Time: 13.14 seconds
# Processing or:country - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7574 - Time: 52.38 seconds
# Processing fc:piece - Total time taken for image size (128, 128): 309.25 seconds
#
# Processing fc:piece - Evaluating for image size: (256, 256)
# Processing or:piece - Params: {'n_estimators': 10, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.8995 - Time: 13.19 seconds
# Processing or:exact_piece - Params: {'n_estimators': 50, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7557 - Time: 54.33 seconds
# ...
#
# Processing fc:country - Test Confusion Matrix:
# [[39  9  2  7  4]
#  [ 5 51  1  3  1]
#  [ 2  2 43  9  5]
#  [ 5  0  6 48  3]
#  [ 8  7  3 12 31]]
# Processing fc:country - Ended at 2024-08-05 22:18:07.601091
# Processing fc:country - Total duration: 0:23:04.398950
# Processing fc:country - Best Parameters identified from the grid search: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1}
# Processing fc:country - Best Image Size identified from the grid search: (256, 256)
# Processing fc:country - Final test results saved to C:\Users\ReCas\OneDrive\Documents\2024_AIMachineLearning\99_Projects\08.DataSets_fc\fc_country_RF_results_20240805_221726.xlsx
# Processing gy:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7663 - Time: 175.09 seconds
# Processing or:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7614 - Time: 170.46 seconds
# Processing fc:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7737 - Time: 169.02 seconds
# Processing gy:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6806 - Time: 80.47 seconds
# Processing or:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.6969 - Time: 80.42 seconds
# Processing fc:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7010 - Time: 80.41 seconds
# Processing gy:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7427 - Time: 132.21 seconds
# Processing gy:exact_piece - Total time taken for image size (256, 256): 842.02 seconds
#
# Processing gy:exact_piece - Best Score: 0.7679859484777518
# Processing gy:exact_piece - Best Parameters: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1}
# Processing gy:exact_piece - Best Image Size: (128, 128)
# Processing gy:exact_piece - Grid search results saved to C:\Users\ReCas\OneDrive\Documents\2024_AIMachineLearning\99_Projects\06.DataSets_gy\gy_exact_piece_RF_results_20240805_222354.xlsx
# Processing gy:exact_piece - Loading and preprocessing test data
# Processing or:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7476 - Time: 131.48 seconds
# Processing fc:exact_piece - Params: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 1} - Mean Score (accuracy): 0.7516 - Time: 132.40 seconds
# Processing gy:exact_piece - Test Accuracy: 0.8137
# Processing gy:exact_piece - Time taken for final training: 19.58 seconds
# Processing gy:exact_piece - Time taken for final prediction: 0.02 seconds
# Processing gy:exact_piece - Test Classification Report:
#                   precision    recall  f1-score   support
#
# 101_100RUS_01INF       1.00      1.00      1.00         7
# 102_100RUS_02TNK       0.80      0.57      0.67         7
# 103_100RUS_03FGT       0.86      0.86      0.86         7
# 104_100RUS_04BMB       1.00      1.00      1.00         7
# 105_100RUS_05DES       0.62      0.83      0.71         6
# 106_100RUS_06TRS       1.00      0.57      0.73         7
# 107_100RUS_07SUB       0.86      0.86      0.86         7
# 108_100RUS_08BAT       0.78      1.00      0.88         7
# 109_100RUS_09CAR       0.50      1.00      0.67         6
# 201_200GER_01INF       0.78      1.00      0.88         7
# 202_200GER_02TNK       1.00      1.00      1.00         7
# 203_200GER_03FGT       0.71      0.71      0.71         7
# 204_200GER_04BMB       0.83      0.83      0.83         6
# 205_200GER_05DES       1.00      0.43      0.60         7
# 206_200GER_06TRS       0.75      0.86      0.80         7
# 207_200GER_07SUB       1.00      0.86      0.92         7
# 208_200GER_08BAT       0.86      0.86      0.86         7
# 209_200GER_09CAR       1.00      0.71      0.83         7
#  301_300UK_01INF       0.67      0.57      0.62         7
#  302_300UK_02TNK       1.00      1.00      1.00         7
#  303_300UK_03FGT       0.86      0.86      0.86         7
#  304_300UK_04BMB       0.60      0.86      0.71         7
#  305_300UK_05DES       0.55      0.86      0.67         7
#  306_300UK_06TRS       1.00      0.86      0.92         7
#  307_300UK_07SUB       0.86      0.86      0.86         7
#  308_300UK_08BAT       0.67      1.00      0.80         6
#  309_300UK_09CAR       1.00      0.67      0.80         6
# 401_400JAP_01INF       0.75      0.86      0.80         7
# 402_400JAP_02TNK       0.83      0.71      0.77         7
# 403_400JAP_03FGT       0.88      1.00      0.93         7
# 404_400JAP_04BMB       1.00      0.57      0.73         7
# 405_400JAP_05DES       0.60      0.86      0.71         7
# 406_400JAP_06TRS       0.83      0.71      0.77         7
# 407_400JAP_07SUB       0.86      0.86      0.86         7
# 408_400JAP_08BAT       0.83      0.71      0.77         7
# 409_400JAP_09CAR       0.86      1.00      0.92         6
# 501_500USA_01INF       0.86      0.86      0.86         7
# 502_500USA_02TNK       0.75      0.86      0.80         7
# 503_500USA_03FGT       1.00      0.86      0.92         7
# 504_500USA_04BMB       1.00      0.67      0.80         6
# 505_500USA_05DES       0.71      0.71      0.71         7
# 506_500USA_06TRS       0.75      1.00      0.86         6
# 507_500USA_07SUB       1.00      0.57      0.73         7
# 508_500USA_08BAT       1.00      0.67      0.80         6
# 509_500USA_09CAR       1.00      0.71      0.83         7
#
#         accuracy                           0.81       306
#        macro avg       0.85      0.81      0.81       306
#     weighted avg       0.85      0.81      0.81       306
#
# Processing gy:exact_piece - Test Confusion Matrix:
# [[7 0 0 ... 0 0 0]
#  [0 4 0 ... 0 0 0]
#  [0 0 6 ... 0 0 0]
#  ...
#  [0 0 0 ... 4 0 0]
#  [0 0 0 ... 0 4 0]
#  [0 0 0 ... 0 0 5]]
# Processing or:exact_piece - Total time taken for image size (256, 256): 821.62 seconds
#
# Processing or:exact_piece - Best Score: 0.7614553362328538
# Processing or:exact_piece - Best Parameters: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1}
# Processing or:exact_piece - Best Image Size: (128, 128)
# Processing or:exact_piece - Grid search results saved to C:\Users\ReCas\OneDrive\Documents\2024_AIMachineLearning\99_Projects\07.DataSets_or\or_exact_piece_RF_results_20240805_222428.xlsx
# Processing or:exact_piece - Loading and preprocessing test data
# Processing gy:exact_piece - Ended at 2024-08-05 22:24:31.225147
# Processing gy:exact_piece - Total duration: 0:29:28.025007
# Processing gy:exact_piece - Best Parameters identified from the grid search: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1}
# Processing gy:exact_piece - Best Image Size identified from the grid search: (128, 128)
# Processing gy:exact_piece - Final test results saved to C:\Users\ReCas\OneDrive\Documents\2024_AIMachineLearning\99_Projects\06.DataSets_gy\gy_exact_piece_RF_results_20240805_222354.xlsx
# Processing fc:exact_piece - Total time taken for image size (256, 256): 816.76 seconds
#
# Processing fc:exact_piece - Best Score: 0.7737002341920375
# Processing fc:exact_piece - Best Parameters: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1}
# Processing fc:exact_piece - Best Image Size: (256, 256)
# Processing fc:exact_piece - Grid search results saved to C:\Users\ReCas\OneDrive\Documents\2024_AIMachineLearning\99_Projects\08.DataSets_fc\fc_exact_piece_RF_results_20240805_222432.xlsx
# Processing fc:exact_piece - Loading and preprocessing test data
# Processing or:exact_piece - Test Accuracy: 0.8105
# Processing or:exact_piece - Time taken for final training: 19.27 seconds
# Processing or:exact_piece - Time taken for final prediction: 0.02 seconds
# Processing or:exact_piece - Test Classification Report:
#                   precision    recall  f1-score   support
#
# 101_100RUS_01INF       0.88      1.00      0.93         7
# 102_100RUS_02TNK       0.83      0.71      0.77         7
# 103_100RUS_03FGT       0.86      0.86      0.86         7
# 104_100RUS_04BMB       0.88      1.00      0.93         7
# 105_100RUS_05DES       0.67      0.67      0.67         6
# 106_100RUS_06TRS       1.00      0.71      0.83         7
# 107_100RUS_07SUB       0.88      1.00      0.93         7
# 108_100RUS_08BAT       0.78      1.00      0.88         7
# 109_100RUS_09CAR       0.67      1.00      0.80         6
# 201_200GER_01INF       0.78      1.00      0.88         7
# 202_200GER_02TNK       0.83      0.71      0.77         7
# 203_200GER_03FGT       0.86      0.86      0.86         7
# 204_200GER_04BMB       0.67      0.67      0.67         6
# 205_200GER_05DES       1.00      0.43      0.60         7
# 206_200GER_06TRS       0.75      0.86      0.80         7
# 207_200GER_07SUB       1.00      0.86      0.92         7
# 208_200GER_08BAT       0.71      0.71      0.71         7
# 209_200GER_09CAR       0.83      0.71      0.77         7
#  301_300UK_01INF       1.00      0.71      0.83         7
#  302_300UK_02TNK       0.75      0.86      0.80         7
#  303_300UK_03FGT       0.88      1.00      0.93         7
#  304_300UK_04BMB       0.60      0.86      0.71         7
#  305_300UK_05DES       0.55      0.86      0.67         7
#  306_300UK_06TRS       1.00      0.86      0.92         7
#  307_300UK_07SUB       0.75      0.86      0.80         7
#  308_300UK_08BAT       0.71      0.83      0.77         6
#  309_300UK_09CAR       0.83      0.83      0.83         6
# 401_400JAP_01INF       0.86      0.86      0.86         7
# 402_400JAP_02TNK       0.83      0.71      0.77         7
# 403_400JAP_03FGT       1.00      0.86      0.92         7
# 404_400JAP_04BMB       0.80      0.57      0.67         7
# 405_400JAP_05DES       0.60      0.86      0.71         7
# 406_400JAP_06TRS       0.83      0.71      0.77         7
# 407_400JAP_07SUB       0.83      0.71      0.77         7
# 408_400JAP_08BAT       1.00      0.71      0.83         7
# 409_400JAP_09CAR       0.86      1.00      0.92         6
# 501_500USA_01INF       0.88      1.00      0.93         7
# 502_500USA_02TNK       0.86      0.86      0.86         7
# 503_500USA_03FGT       0.83      0.71      0.77         7
# 504_500USA_04BMB       0.80      0.67      0.73         6
# 505_500USA_05DES       0.83      0.71      0.77         7
# 506_500USA_06TRS       0.86      1.00      0.92         6
# 507_500USA_07SUB       1.00      0.57      0.73         7
# 508_500USA_08BAT       1.00      0.83      0.91         6
# 509_500USA_09CAR       0.71      0.71      0.71         7
#
#         accuracy                           0.81       306
#        macro avg       0.83      0.81      0.81       306
#     weighted avg       0.83      0.81      0.81       306
#
# Processing or:exact_piece - Test Confusion Matrix:
# [[7 0 0 ... 0 0 0]
#  [1 5 0 ... 0 0 0]
#  [0 0 6 ... 0 0 0]
#  ...
#  [0 0 0 ... 4 0 0]
#  [0 0 0 ... 0 5 0]
#  [0 0 0 ... 0 0 5]]
# Processing or:exact_piece - Ended at 2024-08-05 22:25:07.208305
# Processing or:exact_piece - Total duration: 0:30:04.007164
# Processing or:exact_piece - Best Parameters identified from the grid search: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1}
# Processing or:exact_piece - Best Image Size identified from the grid search: (128, 128)
# Processing or:exact_piece - Final test results saved to C:\Users\ReCas\OneDrive\Documents\2024_AIMachineLearning\99_Projects\07.DataSets_or\or_exact_piece_RF_results_20240805_222428.xlsx
# Processing fc:exact_piece - Test Accuracy: 0.6373
# Processing fc:exact_piece - Time taken for final training: 39.51 seconds
# Processing fc:exact_piece - Time taken for final prediction: 0.04 seconds
# Processing fc:exact_piece - Test Classification Report:
#                   precision    recall  f1-score   support
#
# 101_100RUS_01INF       0.50      0.86      0.63         7
# 102_100RUS_02TNK       0.80      0.57      0.67         7
# 103_100RUS_03FGT       0.80      0.57      0.67         7
# 104_100RUS_04BMB       0.50      0.29      0.36         7
# 105_100RUS_05DES       0.40      0.33      0.36         6
# 106_100RUS_06TRS       0.75      0.43      0.55         7
# 107_100RUS_07SUB       0.75      0.86      0.80         7
# 108_100RUS_08BAT       0.67      0.86      0.75         7
# 109_100RUS_09CAR       0.86      1.00      0.92         6
# 201_200GER_01INF       0.88      1.00      0.93         7
# 202_200GER_02TNK       0.67      0.57      0.62         7
# 203_200GER_03FGT       0.80      0.57      0.67         7
# 204_200GER_04BMB       0.50      0.50      0.50         6
# 205_200GER_05DES       0.33      0.29      0.31         7
# 206_200GER_06TRS       0.71      0.71      0.71         7
# 207_200GER_07SUB       1.00      0.86      0.92         7
# 208_200GER_08BAT       0.62      0.71      0.67         7
# 209_200GER_09CAR       1.00      0.71      0.83         7
#  301_300UK_01INF       0.80      0.57      0.67         7
#  302_300UK_02TNK       1.00      0.86      0.92         7
#  303_300UK_03FGT       0.75      0.86      0.80         7
#  304_300UK_04BMB       0.50      0.57      0.53         7
#  305_300UK_05DES       0.23      0.71      0.34         7
#  306_300UK_06TRS       1.00      0.71      0.83         7
#  307_300UK_07SUB       0.86      0.86      0.86         7
#  308_300UK_08BAT       0.57      0.67      0.62         6
#  309_300UK_09CAR       1.00      0.67      0.80         6
# 401_400JAP_01INF       0.40      0.86      0.55         7
# 402_400JAP_02TNK       0.56      0.71      0.62         7
# 403_400JAP_03FGT       0.71      0.71      0.71         7
# 404_400JAP_04BMB       0.57      0.57      0.57         7
# 405_400JAP_05DES       1.00      0.57      0.73         7
# 406_400JAP_06TRS       0.62      0.71      0.67         7
# 407_400JAP_07SUB       0.50      0.29      0.36         7
# 408_400JAP_08BAT       0.83      0.71      0.77         7
# 409_400JAP_09CAR       0.43      0.50      0.46         6
# 501_500USA_01INF       1.00      0.29      0.44         7
# 502_500USA_02TNK       0.83      0.71      0.77         7
# 503_500USA_03FGT       0.80      0.57      0.67         7
# 504_500USA_04BMB       0.67      0.33      0.44         6
# 505_500USA_05DES       0.60      0.43      0.50         7
# 506_500USA_06TRS       0.67      0.67      0.67         6
# 507_500USA_07SUB       0.50      0.71      0.59         7
# 508_500USA_08BAT       0.67      0.33      0.44         6
# 509_500USA_09CAR       0.45      0.71      0.56         7
#
#         accuracy                           0.64       306
#        macro avg       0.69      0.63      0.64       306
#     weighted avg       0.69      0.64      0.64       306
#
# Processing fc:exact_piece - Test Confusion Matrix:
# [[6 0 0 ... 0 0 0]
#  [1 4 0 ... 0 0 0]
#  [0 0 4 ... 0 0 0]
#  ...
#  [0 0 0 ... 5 0 0]
#  [0 0 0 ... 0 2 1]
#  [0 0 0 ... 0 0 5]]
# Processing fc:exact_piece - Ended at 2024-08-05 22:25:34.085086
# Processing fc:exact_piece - Total duration: 0:30:30.881945
# Processing fc:exact_piece - Best Parameters identified from the grid search: {'n_estimators': 100, 'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 1}
# Processing fc:exact_piece - Best Image Size identified from the grid search: (256, 256)
# Processing fc:exact_piece - Final test results saved to C:\Users\ReCas\OneDrive\Documents\2024_AIMachineLearning\99_Projects\08.DataSets_fc\fc_exact_piece_RF_results_20240805_222432.xlsx
# Overall processing ended at 2024-08-05 22:25:34.168153
# Total duration for all models: 0:30:30.971012
